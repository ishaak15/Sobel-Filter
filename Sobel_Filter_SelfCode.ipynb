# %%
#imports

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2

# %%
from google.colab import files

from io import BytesIO
from PIL import Image

uploaded = files.upload()
im = Image.open(BytesIO(uploaded['rose.jpg']))
# Out:
#      <input type="file" id="files-b8177e78-208c-4c9d-9ff5-f79589866178" name="files[]" multiple disabled />
#      <output id="result-b8177e78-208c-4c9d-9ff5-f79589866178">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving rose.jpg to rose (1).jpg

# %%
plt.imshow(im)
plt.show()

# %%
images = np.array(Image.open('rose.jpg'))

gray = cv2.cvtColor(images, cv2.COLOR_RGB2GRAY)

plt.imshow(gray, cmap='gray')

# %%
plt.imshow(img)
plt.show()

# %%
# Create a custom kernel

# 3x3 array for edge detection
sobel_y = np.array([[ -1, -2, -1], 
                   [ 0, 0, 0], 
                   [ 1, 2, 1]])

## TODO: Create and apply a Sobel x operator
sobel_x = np.array([[-1, 0, 1],
                    [-2,0,2],
                    [-1, 0, 1]])


# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
filtered_image = cv2.filter2D(gray, -1, sobel_y)

plt.imshow(filtered_image, cmap='gray')

# %%
filtered_image = cv2.filter2D(gray, -1, sobel_x)

plt.imshow(filtered_image, cmap='gray')

# %%
sobel_five = np.array([[-1,-1,-2,-1,-1],
                          [-1,-1,-2,-1,-1],
                          [0,0,0,0,0],
                          [1,1,2,1,1],
                         [1,1,2,1,1]])
# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
filtered_image = cv2.filter2D(gray, -1, sobel_five)

plt.imshow(filtered_image, cmap='gray')
